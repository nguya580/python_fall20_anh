# %% [markdown]
# ### Exercise 1:
# Study the following code and create your own mad-libs generator (please don't copy the example)

# %% [markdown]
# ### A Mad-Libs invitation generator
#
# Mad-Libs is a phrasal template word game where one player prompts others for a list of words to <b>substitute</b> for blanks in a story.
#
# We are going to create an event `invitation function` that would allow us to automate creating copies of event invitations.
#
# <span style="color:tomato">The invitation template</span>:
# ```
#     Hey, _guestname_!
#     You are invited to a _type_of_event_! Join us on _date_ at _location_!
#     Bring _items_.
#
#     Best,
#     Party bear
#
# ```
#
# <span style="color:tomato">An example output</span>:
# ```
#     Hey, Sven!
#     You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#     Bring beverages, games, signs, masks, and facecovers.
#
#     Best,
#     Party bear
# ```

# %%
# EXAMPLE GENERATOR

import random
def event(namelist, event_type, date, loc, items):
    """
        This function takes event information input, parse them and turn them into
        a formatted invitation that's ready to be duplicate and populate.
    """
    # outputs a random item from the list
    def getRand(list):
        return random.choice(list)
    
    # formats all outputs form a list as 'a, b, and c'
    def getAll(li):
        return ', '.join(li[:-1]) + ", and %s" %(li[-1])
    
  
    # variables needed:
    guestlist = namelist
    type_of_event = event_type
    date = date[::-1]
    location = loc[::-1] # a simple reversed encrption
    items = items
    invite_template = '''
            Hey %s:
            You are invited to a %s! Join us on %s at %s!
            Bring %s.

            Best,
            Party bear

            ---
        ''' 
    
    # loop through all guest tuples in the guestlist
    # populate our invitations
    for guests in guestlist:
        print(invite_template % (guests,
                                 type_of_event,
                                 date,
                                 location,
                                 getAll(items)# try getRand()
                                ))

# %%
guests = ("Bob","Mary & Friends","Lan","Anna","Sven and friends","Jason")
items = ['beverages','games','signs',"masks","facecovers"]

# call the generator function to populate invitations:
event(guests, "gathering", "July 2nd", "Union Square", items)
# Out:
#             Hey Bob:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---
#
#
#             Hey Mary & Friends:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---
#
#
#             Hey Lan:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---
#
#
#             Hey Anna:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---
#
#
#             Hey Sven and friends:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---
#
#
#             Hey Jason:
#             You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#             Bring beverages, games, signs, masks, and facecovers.
#
#             Best,
#             Party bear
#
#             ---

# %%
# Exercise 1 Code Here:
guestList = ("Anh", "Paras", "Linh", "Chi", "Thy", "Sven", "Sohee")
objects = ["Cheestos", "spinach dip", "tortilla chips", "Coke", "popcorn"]

import random
def invitation_template(guestList, eventName, location, objects, date, time):
    ''' the function store template for the invitation '''
    location = location[::- 1]

    for guest in guestList:
        print(f''' Hello {guest},
        I invite you to join {eventName} with me and Teddy at {location}.
        Please come on time at {time} on the date of {date}.
        Please bring {random_object(objects)} to the movie night

        See you all,
        Anh and Teddy the shibe.

        ********\n''')

        
def random_object(list):
    """ this function returns random object that participants will bring """

    return random.choice(list)


def all_objects(list):
    """ this function returns all the objects within the object[list] """

    return ', '.join(list[0:-1]) + ', and %s' %(list[-1]) #[::-1] is anything before the last index in list, [0:-1] is from the 1st index to the second to last index

#invitation_template(guestList, eventName, location, objects, date, time)
invitation_template(guestList, 'horror movie night', '123 Spinach st, apt 6F, 11102', objects, 'Nov 20, 2021', '7 PM')
# Out:
#  Hello Anh,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring tortilla chips to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Paras,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring popcorn to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Linh,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring popcorn to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Chi,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring tortilla chips to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Thy,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring tortilla chips to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Sven,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring spinach dip to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********
#
#  Hello Sohee,
#         I invite you to join horror movie night with me and Teddy at 20111 ,F6 tpa ,ts hcanipS 321.
#         Please come on time at 7 PM on the date of Nov 20, 2021.
#         Please bring popcorn to the movie night
#
#         See you all,
#         Anh and Teddy the shibe.
#
#         ********

# %% [markdown]
# ### Exercise 2:
#
# ### What is a palindrome?
# A palindrome is a word or phrase that is spelled the same forwards as backwards, like:
#
# ```
# wow
# Anna
# race car
# Was it a cat I saw?
# ```
#
# Create a function that checks whether or not a given phrase is a palindrome. Here's the plan:
# * Our function will be called `isPalindrome()`.
# * It will accept one **argument** called `txt`, which is a string.
# * It will print True if `txt` is a palindrome or `False` if `txt`
#   is not a palindrome.
#
# ### Test your function along the way
# We will use the following test cases to guide us:
#
# The following should all return `True`:
# ```
# isPalindrome('wow')
# isPalindrome('12a3a21')
# isPalindrome('Anna')
# isPalindrome('race car')
# isPalindrome('Was it a cat I saw?')
# ```
#
# The following should all return `False`:
# ```
# isPalindrome('wowza')
# isPalindrome('123a21')
# isPalindrome('<3 mom <3')
# ```
#
# ### Things to Consider:
#  - Make everything lowercase.
#  - Replace all spaces with an empty string
#  - Replace all spaces with an empty string
#  - How would we spell a word backwards or forwards?

# %%
# Exercise 2 Code Here:
def checkPalindrome():
    ''' this f tests where a sentence is a Palindrome. '''

    txt = input("Please type your sentence: ")

    unwanted = ['?', ':', ',', '!', ';']

    #remove unwanted characters
    new_txt = txt
    for char in unwanted:
        new_txt = new_txt.replace(char, "")

    txt_lower = new_txt.lower()
    txt_spaceClear = txt_lower.replace(' ', '')

    txt_Palindrome = txt_spaceClear[::-1]

    if txt_Palindrome == txt_spaceClear:
        print(f'\nTrue. "{txt}" is a Palindrome.')
    else:
        print(f'\nFalse. "{txt}" is not a Palindrome.')

    checkP_again()

def checkP_again():
    choice = input("""\nDo you want to check another phrase?
Enter 'y' to continue, or 'n' to exit.""")

    if choice == 'y':
        checkPalindrome()
    elif choice == 'n':
        print("\nBye bye.")

checkPalindrome()
# Out:
# Please type your sentence: 123
#
# False. "123" is not a Palindrome.
#
# Do you want to check another phrase?
# Enter 'y' to continue, or 'n' to exit.y
# Please type your sentence: Eva, can I see bees in a cave?
#
# True. "Eva, can I see bees in a cave?" is a Palindrome.
#
# Do you want to check another phrase?
# Enter 'y' to continue, or 'n' to exit.n
#
# Bye bye.

# %% [markdown]
# ### Exercise 3:
# Create a dataset of your own using using a dictionary and make a simple visualization with it. Branch out and see what types of graphs you could use here: https://matplotlib.org/ . Don't be shy to Google things you don't know!!!

# %%
# Exercise 3 Code Here:
import matplotlib.pyplot as plt

data = {'Youtube': 6, 'Instagram': 3, 'Facebook': 2, 'Chrome': 1}

plt.plot(range(len(data)), list(data.values()), color = '#F3872F')
plt.ylabel('Hours')

plt.xticks(range(len(data)), list(data.keys()), rotation = 45,)

plt.suptitle('Most used apps screen time of Anh')

plt.show()
