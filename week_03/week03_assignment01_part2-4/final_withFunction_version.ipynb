# %%
from newsapi import NewsApiClient
import csv

# Init
newsapi = NewsApiClient(api_key='fdde27f8887d4a01bf80ebfe6a20295e')

# %%
sources = newsapi.get_sources()

#check how many news media id the API offers
for source in sources['sources']:
    print(source['id'] + '\n' + source['language'] + '\n' + source['country'] + '\n\n')
# Out:
# abc-news
# en
# us
#
#
# abc-news-au
# en
# au
#
#
# aftenposten
# no
# no
#
#
# al-jazeera-english
# en
# us
#
#
# ansa
# it
# it
#
#
# argaam
# ar
# sa
#
#
# ars-technica
# en
# us
#
#
# ary-news
# ud
# pk
#
#
# associated-press
# en
# us
#
#
# australian-financial-review
# en
# au
#
#
# axios
# en
# us
#
#
# bbc-news
# en
# gb
#
#
# bbc-sport
# en
# gb
#
#
# bild
# de
# de
#
#
# blasting-news-br
# pt
# br
#
#
# bleacher-report
# en
# us
#
#
# bloomberg
# en
# us
#
#
# breitbart-news
# en
# us
#
#
# business-insider
# en
# us
#
#
# business-insider-uk
# en
# gb
#
#
# buzzfeed
# en
# us
#
#
# cbc-news
# en
# ca
#
#
# cbs-news
# en
# us
#
#
# cnn
# en
# us
#
#
# cnn-es
# es
# us
#
#
# crypto-coins-news
# en
# us
#
#
# der-tagesspiegel
# de
# de
#
#
# die-zeit
# de
# de
#
#
# el-mundo
# es
# es
#
#
# engadget
# en
# us
#
#
# entertainment-weekly
# en
# us
#
#
# espn
# en
# us
#
#
# espn-cric-info
# en
# us
#
#
# financial-post
# en
# ca
#
#
# focus
# de
# de
#
#
# football-italia
# en
# it
#
#
# fortune
# en
# us
#
#
# four-four-two
# en
# gb
#
#
# fox-news
# en
# us
#
#
# fox-sports
# en
# us
#
#
# globo
# pt
# br
#
#
# google-news
# en
# us
#
#
# google-news-ar
# es
# ar
#
#
# google-news-au
# en
# au
#
#
# google-news-br
# pt
# br
#
#
# google-news-ca
# en
# ca
#
#
# google-news-fr
# fr
# fr
#
#
# google-news-in
# en
# in
#
#
# google-news-is
# he
# is
#
#
# google-news-it
# it
# it
#
#
# google-news-ru
# ru
# ru
#
#
# google-news-sa
# ar
# sa
#
#
# google-news-uk
# en
# gb
#
#
# goteborgs-posten
# se
# se
#
#
# gruenderszene
# de
# de
#
#
# hacker-news
# en
# us
#
#
# handelsblatt
# de
# de
#
#
# ign
# en
# us
#
#
# il-sole-24-ore
# it
# it
#
#
# independent
# en
# gb
#
#
# infobae
# es
# ar
#
#
# info-money
# pt
# br
#
#
# la-gaceta
# es
# ar
#
#
# la-nacion
# es
# ar
#
#
# la-repubblica
# it
# it
#
#
# le-monde
# fr
# fr
#
#
# lenta
# ru
# ru
#
#
# lequipe
# fr
# fr
#
#
# les-echos
# fr
# fr
#
#
# liberation
# fr
# fr
#
#
# marca
# es
# es
#
#
# mashable
# en
# us
#
#
# medical-news-today
# en
# us
#
#
# msnbc
# en
# us
#
#
# mtv-news
# en
# us
#
#
# mtv-news-uk
# en
# gb
#
#
# national-geographic
# en
# us
#
#
# national-review
# en
# us
#
#
# nbc-news
# en
# us
#
#
# news24
# en
# za
#
#
# new-scientist
# en
# us
#
#
# news-com-au
# en
# au
#
#
# newsweek
# en
# us
#
#
# new-york-magazine
# en
# us
#
#
# next-big-future
# en
# us
#
#
# nfl-news
# en
# us
#
#
# nhl-news
# en
# us
#
#
# nrk
# no
# no
#
#
# politico
# en
# us
#
#
# polygon
# en
# us
#
#
# rbc
# ru
# ru
#
#
# recode
# en
# us
#
#
# reddit-r-all
# en
# us
#
#
# reuters
# en
# us
#
#
# rt
# ru
# ru
#
#
# rte
# en
# ie
#
#
# rtl-nieuws
# nl
# nl
#
#
# sabq
# ar
# sa
#
#
# spiegel-online
# de
# de
#
#
# svenska-dagbladet
# se
# se
#
#
# t3n
# de
# de
#
#
# talksport
# en
# gb
#
#
# techcrunch
# en
# us
#
#
# techcrunch-cn
# zh
# zh
#
#
# techradar
# en
# us
#
#
# the-american-conservative
# en
# us
#
#
# the-globe-and-mail
# en
# ca
#
#
# the-hill
# en
# us
#
#
# the-hindu
# en
# in
#
#
# the-huffington-post
# en
# us
#
#
# the-irish-times
# en
# ie
#
#
# the-jerusalem-post
# en
# is
#
#
# the-lad-bible
# en
# gb
#
#
# the-next-web
# en
# us
#
#
# the-sport-bible
# en
# gb
#
#
# the-times-of-india
# en
# in
#
#
# the-verge
# en
# us
#
#
# the-wall-street-journal
# en
# us
#
#
# the-washington-post
# en
# us
#
#
# the-washington-times
# en
# us
#
#
# time
# en
# us
#
#
# usa-today
# en
# us
#
#
# vice-news
# en
# us
#
#
# wired
# en
# us
#
#
# wired-de
# de
# de
#
#
# wirtschafts-woche
# de
# de
#
#
# xinhua-net
# zh
# zh
#
#
# ynet
# he
# is

# %%
def list_to_string(list, string_name):
    ''' this function convert list to string, because newsapi uses string for input '''
    string_name = ', '.join(list) #join a list using ', ' as indicators

# %%
def getnews_en_us(list, output_list):
    ''' this function get a list of news sources id in English within the US '''

    en_us_filter = []

    #filter through to get a list of source in en and US
    for source in list:
        if source["language"] == "en" and source["country"] == "us":
            en_us_filter.append(source)

    en_us_filter

    #filter only the source ID in en and US
    output_list = []
    for item in en_us_filter:
        id = item['id']
        output_list.append(id)

# %%
#create a list of news id written in English within the US
en_us_news = []
getnews_en_us(sources['sources'], en_us_news)
news_en_us = en_us_news

#converse the list into a string of news id
src_tostring = ''
list_to_string(news_en_us, src_tostring)

# %%
def news_searchengine():
    print('''The application helps you search for news articles from the last 30 days.
Your results will be saved as a CSV file as "news_fromkeyword_python.csv". \n''')

    keyword = input(str('Enter a keyword you want to search: '))

    top_headlines = newsapi.get_top_headlines(q = keyword, sources = src_tostring)
    # print(top_headlines)

    #creat and open a cvs file
    csv_file = open('news_fromkeyword_python.csv', 'w')
    csv_writer = csv.writer(csv_file)

    #the first row of csv file
    csv_writer.writerow(['Published date', 'Title', 'Summary', 'Link'])

    for article in top_headlines['articles']:
        date = article['publishedAt']
        print('Published date: ' + date)

        headline = article['title']
        print('Title: ' + headline)

        summary = article['description']
        print('Summary: ' + summary + '\n')

        link = article['url']
        print('Link: ' + link + '\n\n')

        #write row for every founded article
        csv_writer.writerow([date, headline, summary, link])

    csv_file.close()

# %%
news_searchengine()
# Out:
# The application helps you search for news articles from the last 30 days.
# Your results will be saved as a CSV file as "news_fromkeyword_python.csv".
#
# Enter a keyword you want to search: white house
# Published date: 2020-11-14T17:45:29Z
# Title: Trump thrills protesting supporters with motorcade drive-by
# Summary: WASHINGTON (AP) — President Donald Trump delighted supporters gathered near the White House on Saturday with a slow motorcade drive-by through downtown Washington on the way to his Virginia golf...
