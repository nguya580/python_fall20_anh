# %%
from newsapi import NewsApiClient
import csv

# Init
newsapi = NewsApiClient(api_key='fdde27f8887d4a01bf80ebfe6a20295e')

# %%
sources = newsapi.get_sources()

#check how many news media id the API offers
for source in sources['sources']:
    print(source['id'] + '\n' + source['language'] + '\n' + source['country'] + '\n\n')
# Out:
# abc-news
# en
# us
#
#
# abc-news-au
# en
# au
#
#
# aftenposten
# no
# no
#
#
# al-jazeera-english
# en
# us
#
#
# ansa
# it
# it
#
#
# argaam
# ar
# sa
#
#
# ars-technica
# en
# us
#
#
# ary-news
# ud
# pk
#
#
# associated-press
# en
# us
#
#
# australian-financial-review
# en
# au
#
#
# axios
# en
# us
#
#
# bbc-news
# en
# gb
#
#
# bbc-sport
# en
# gb
#
#
# bild
# de
# de
#
#
# blasting-news-br
# pt
# br
#
#
# bleacher-report
# en
# us
#
#
# bloomberg
# en
# us
#
#
# breitbart-news
# en
# us
#
#
# business-insider
# en
# us
#
#
# business-insider-uk
# en
# gb
#
#
# buzzfeed
# en
# us
#
#
# cbc-news
# en
# ca
#
#
# cbs-news
# en
# us
#
#
# cnn
# en
# us
#
#
# cnn-es
# es
# us
#
#
# crypto-coins-news
# en
# us
#
#
# der-tagesspiegel
# de
# de
#
#
# die-zeit
# de
# de
#
#
# el-mundo
# es
# es
#
#
# engadget
# en
# us
#
#
# entertainment-weekly
# en
# us
#
#
# espn
# en
# us
#
#
# espn-cric-info
# en
# us
#
#
# financial-post
# en
# ca
#
#
# focus
# de
# de
#
#
# football-italia
# en
# it
#
#
# fortune
# en
# us
#
#
# four-four-two
# en
# gb
#
#
# fox-news
# en
# us
#
#
# fox-sports
# en
# us
#
#
# globo
# pt
# br
#
#
# google-news
# en
# us
#
#
# google-news-ar
# es
# ar
#
#
# google-news-au
# en
# au
#
#
# google-news-br
# pt
# br
#
#
# google-news-ca
# en
# ca
#
#
# google-news-fr
# fr
# fr
#
#
# google-news-in
# en
# in
#
#
# google-news-is
# he
# is
#
#
# google-news-it
# it
# it
#
#
# google-news-ru
# ru
# ru
#
#
# google-news-sa
# ar
# sa
#
#
# google-news-uk
# en
# gb
#
#
# goteborgs-posten
# se
# se
#
#
# gruenderszene
# de
# de
#
#
# hacker-news
# en
# us
#
#
# handelsblatt
# de
# de
#
#
# ign
# en
# us
#
#
# il-sole-24-ore
# it
# it
#
#
# independent
# en
# gb
#
#
# infobae
# es
# ar
#
#
# info-money
# pt
# br
#
#
# la-gaceta
# es
# ar
#
#
# la-nacion
# es
# ar
#
#
# la-repubblica
# it
# it
#
#
# le-monde
# fr
# fr
#
#
# lenta
# ru
# ru
#
#
# lequipe
# fr
# fr
#
#
# les-echos
# fr
# fr
#
#
# liberation
# fr
# fr
#
#
# marca
# es
# es
#
#
# mashable
# en
# us
#
#
# medical-news-today
# en
# us
#
#
# msnbc
# en
# us
#
#
# mtv-news
# en
# us
#
#
# mtv-news-uk
# en
# gb
#
#
# national-geographic
# en
# us
#
#
# national-review
# en
# us
#
#
# nbc-news
# en
# us
#
#
# news24
# en
# za
#
#
# new-scientist
# en
# us
#
#
# news-com-au
# en
# au
#
#
# newsweek
# en
# us
#
#
# new-york-magazine
# en
# us
#
#
# next-big-future
# en
# us
#
#
# nfl-news
# en
# us
#
#
# nhl-news
# en
# us
#
#
# nrk
# no
# no
#
#
# politico
# en
# us
#
#
# polygon
# en
# us
#
#
# rbc
# ru
# ru
#
#
# recode
# en
# us
#
#
# reddit-r-all
# en
# us
#
#
# reuters
# en
# us
#
#
# rt
# ru
# ru
#
#
# rte
# en
# ie
#
#
# rtl-nieuws
# nl
# nl
#
#
# sabq
# ar
# sa
#
#
# spiegel-online
# de
# de
#
#
# svenska-dagbladet
# se
# se
#
#
# t3n
# de
# de
#
#
# talksport
# en
# gb
#
#
# techcrunch
# en
# us
#
#
# techcrunch-cn
# zh
# zh
#
#
# techradar
# en
# us
#
#
# the-american-conservative
# en
# us
#
#
# the-globe-and-mail
# en
# ca
#
#
# the-hill
# en
# us
#
#
# the-hindu
# en
# in
#
#
# the-huffington-post
# en
# us
#
#
# the-irish-times
# en
# ie
#
#
# the-jerusalem-post
# en
# is
#
#
# the-lad-bible
# en
# gb
#
#
# the-next-web
# en
# us
#
#
# the-sport-bible
# en
# gb
#
#
# the-times-of-india
# en
# in
#
#
# the-verge
# en
# us
#
#
# the-wall-street-journal
# en
# us
#
#
# the-washington-post
# en
# us
#
#
# the-washington-times
# en
# us
#
#
# time
# en
# us
#
#
# usa-today
# en
# us
#
#
# vice-news
# en
# us
#
#
# wired
# en
# us
#
#
# wired-de
# de
# de
#
#
# wirtschafts-woche
# de
# de
#
#
# xinhua-net
# zh
# zh
#
#
# ynet
# he
# is

# %%
def list_to_string(list, string_name):
    ''' this function convert list to string, because newsapi uses string for input '''
    string_name = ', '.join(list)

# %%
def news_searchengine():
    print('''The application helps you search for news articles from the last 30 days.
Your results will be saved as a CSV file as "news_fromkeyword_python.csv". \n''')

    keyword = input(str('Enter a keyword you want to search: '))

    #sources list in English in the US
    sources_list = ['abc-news', 'bbc-news', 'bloomberg', 'business-insider', 'cbs-news', 'cnn', 'google-news', 'nbc-news', 'new-york-magazine', 'politico', 'reuters', 'the-verge', 'the-wall-street-journal', 'the-washington-post', 'the-washington-times', 'time', 'vice-news']

    #use function to convert list to string
    src_tostring = ''
    list_to_string(sources_list, src_tostring)

    #check if string from sources_list is print out correctly
    print(src_tostring)

    top_headlines = newsapi.get_top_headlines(q = keyword, sources = src_tostring)
    # print(top_headlines)

    #creat and open a cvs file
    csv_file = open('news_fromkeyword_python.csv', 'w')
    csv_writer = csv.writer(csv_file)

    #the first row of csv file
    csv_writer.writerow(['Published date', 'Title', 'Summary', 'Link'])

    for article in top_headlines['articles']:
        date = article['publishedAt']
        print('Published date: ' + date)

        headline = article['title']
        print('Title: ' + headline)

        summary = article['description']
        print('Summary: ' + summary + '\n')

        link = article['url']
        print('Link: ' + link + '\n\n')

        #write row for every founded article
        csv_writer.writerow([date, headline, summary, link])

    csv_file.close()

# %%
news_searchengine()
# Out:
# The application helps you search for news articles from the last 30 days.
# Your results will be saved as a CSV file as "news_fromkeyword_python.csv".
#
# Enter a keyword you want to search: biden
#
# Published date: 2020-11-13T21:13:30+00:00
# Title: Gillibrand says Biden will be "reinventing the wheel" with government's COVID response
# Summary: The New York senator said that it was "problematic" that the formal presidential transition process has not yet begun.
#
# Link: https://www.cbsnews.com/news/gillibrand-says-biden-will-be-reinventing-the-wheel-with-governments-covid-response/
#
#
# Published date: 2020-11-13T21:07:16Z
# Title: US election live: China congratulates Joe Biden on victory over Donald Trump
# Summary: Welcome to our live coverage of the continued fallout from the US election.
#
# Link: https://www.news.com.au/world/north-america/us-politics/us-election-2020-live-updates-china-congratulates-joe-biden-on-victory-over-donald-trump/live-coverage/6ff11b1a0af8efac0d5356f55ce85439
#
#
# Published date: 2020-11-13T21:06:48Z
# Title: U.S. Presidential polls | Biden wins Georgia, solidifies victory with 306 votes
# Summary: Though Mr. Trump with 232 votes had yet to concede, Biden officials reiterated they were moving ahead with transition efforts regardless.
#
# Link: https://www.thehindu.com/news/international/us-presidential-polls-biden-wins-georgia-solidifies-victory-with-306-votes/article33098416.ece
#
#
# Published date: 2020-11-13T21:04:12+00:00
# Title: Biden transition team pushes for access to intelligence briefings
# Summary: President-elect Joe BIden's transition team held a press conference Friday as the Trump administration continues to impede Biden's access to intelligence briefings. CBS News political correspondent Ed O'Keefe joined CBSN with the latest on the transition proc…
#
# Link: https://www.cbsnews.com/video/biden-transition-team-gsa-intelligence-briefings/
#
#
# Published date: 2020-11-13T21:01:00Z
# Title: With final states called, Biden's projected Electoral College victory matches Trump's in 2016
# Summary: Biden is apparent winner in Georgia, NBC News projects, bringing Electoral College vote total to 306
#
# Link: https://www.nbcnews.com/politics/2020-election/final-states-called-biden-s-projected-electoral-college-victory-matches-n1247766
#
#
# Published date: 2020-11-13T20:57:06Z
# Title: Pompeo congratulates other countries on elections, refuses to recognize US results - Business Insider
# Summary: Secretary of State Mike Pompeo just left on a 10-day trip to seven countries with leaders that have congratulated Biden on his 2020 victory.
#
# Link: http://www.businessinsider.com/pompeo-congratulates-other-countries-elections-refuses-to-recognize-us-results-2020-11
#
#
# Published date: 2020-11-13T20:57:06Z
# Title: Pompeo congratulates other countries on elections, refuses to recognize US results - Business Insider
# Summary: Secretary of State Mike Pompeo just left on a 10-day trip to seven countries with leaders that have congratulated Biden on his 2020 victory.
#
# Link: http://uk.businessinsider.com/pompeo-congratulates-other-countries-elections-refuses-to-recognize-us-results-2020-11
#
#
# Published date: 2020-11-13T20:48:25+00:00
# Title: More than 100 Secret Service officers infected with COVID-19 or quarantining as virus surges across country
# Summary: The outbreak is reported following the close of a campaign season that featured Trump rallies and lower-profile Biden events prior to Election Day
#
# Link: https://www.usatoday.com/story/news/politics/2020/11/13/coronavirus-more-than-100-secret-service-officers-infected-isolating/6278424002/
#
#
# Published date: 2020-11-13T20:45:38Z
# Title: The Week in Pictures: Nov. 5 - 12
# Summary: Biden supporters celebrate election win, Trump's base remains defiant, and more.
#
# Link: https://www.nbcnews.com/slideshow/week-pictures-virus-rise-push-punishments-n1247628
#
#
# Published date: 2020-11-13T20:41:00Z
# Title: YouTube says it wants 'discussion' of election results, even when it's been debunked
# Summary: YouTube is more hands-off than Facebook or Twitter with videos challenging the election results for President-elect Joe Biden's defeat of President Donald Trump
#
# Link: https://www.nbcnews.com/tech/social-media/youtube-says-it-wants-discussion-election-results-even-when-it-n1247764
#
#
# Published date: 2020-11-13T20:30:00Z
# Title: Opinion: There is method in Trump’s madness in trying to block Biden
# Summary: While Trump is aware he can’t reverse the election verdict, he knows he can profit from his treachery in attempting to do so
#
# Link: https://www.theglobeandmail.com/opinion/article-there-is-method-in-trumps-madness-in-trying-to-block-biden/
#
#
# Published date: 2020-11-13T20:26:20Z
# Title: Joe Biden wins White House with 306 electoral votes
# Summary: Democrat Joe Biden has solidified his victory over Donald Trump in the US election with a win in traditionally Republican-leaning Georgia, putting him at 306 electoral votes, networks have projected.
#
# Link: https://www.rte.ie/news/us-election-2020/2020/1113/1178053-us-election/
#
#
# Published date: 2020-11-13T20:07:22.086881Z
# Title: Biden's picks for transition team the latest sign of a radically different approach to immigration
# Summary: President-elect Joe Biden is months away from taking office, and he hasn’t named his Cabinet yet, but there are already signs from his transition team of the radically different approach to immigration he intends to take once in office.
#
# Link: https://www.foxnews.com/politics/bidens-transition-team-dhs-immigration
#
#
# Published date: 2020-11-13T20:05:40Z
# Title: For Stacey Abrams, revenge is a dish best served blue
# Summary: President-elect Joe Biden is the first Democratic presidential candidate to win Georgia in 28 years, and much of the credit for his showing here is going to someone who wasn't on the ballot: Stacey Abrams.
#
# Link: http://us.cnn.com/2020/11/07/us/stacey-abrams-georgia-voter-suppression-trnd/index.html
#
#
# Published date: 2020-11-13T19:55:13Z
# Title: Pope Francis congratulates Joe Biden on election win
# Summary: Biden reportedly said that he hopes to work with Francis on issues such as climate change, poverty and immigration.
#
# Link: http://www.aljazeera.com/news/2020/11/13/vatican-calling-pope-congratulates-joe-biden-on-election
#
#
# Published date: 2020-11-13T19:52:21.2337628Z
# Title: Native Americans In Arizona Vote For BIden Amid COVID-19
# Summary: “This is us saying: COVID-19 is a monster that has come into our communities and devastated our people, but we’re still going to show up,” one citizen of the Navajo Nation told BuzzFeed News.
#
# Link: https://www.buzzfeednews.com/article/clarissajanlim/native-american-voters-arizona-biden-coronavirus
#
#
# Published date: 2020-11-13T19:33:40Z
# Title: Biden projected to upset Trump in Georgia | TheHill
# Summary: Former Vice President Joe Biden is projected to win the presidential race in Georgia, becoming th...
#
# Link: http://thehill.com/homenews/campaign/524351-biden-upsets-trump-in-georgia
#
#
# Published date: 2020-11-13T19:27:12Z
# Title: Joe Biden becomes first Democrat in 28 years to win Georgia
# Summary: Joe Biden will win Georgia, CNN projected Friday, striking at the heart of what has been a Republican presidential stronghold for nearly three decades. The former vice president is the first Democratic nominee to triumph in Georgia since Bill Clinton did it i…
#
# Link: http://us.cnn.com/2020/11/13/politics/joe-biden-wins-georgia/index.html
#
#
# Published date: 2020-11-13T19:23:43Z
# Title: Trump to deliver public remarks on COVID-19 vaccine developments today
# Summary: President Donald Trump’s refusal to take aggressive action on the pandemic or to co-ordinate with Joe Biden’s team will worsen the effects of the virus, experts worry
#
# Link: https://www.theglobeandmail.com/world/article-trump-says-hell-do-the-right-thing-after-all-votes-are-counted-2/
#
#
# Published date: 2020-11-13T19:07:28.0627632Z
# Title: Vaccine tsar calls on Trump to allow contact with Biden
# Summary: Head of Operation Warp Speed warns thousands of lives at stake if project is interrupted
#
# Link: https://www.ft.com/content/1ce353bd-45fb-47f4-861f-3deaa4965b61
